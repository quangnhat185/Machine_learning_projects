# %%
import cv2
import matplotlib.pyplot as plt
from lib_detection import load_model, detect_lp, im2single
img_path = "test.jpg"

# %%
wpod_net_path = "wpod-net_update1.json"
wpod_net = load_model(wpod_net_path)

# %%
Ivehicle = plt.imread("test.jpg")
plt.imshow(Ivehicle)

# %%
Dmax = 608
Dmin = 288

ratio = float(max(Ivehicle.shape[:2])) / min(Ivehicle.shape[:2])
side = int(ratio * Dmin)
bound_dim = min(side, Dmax)

_ , LpImg, lp_type = detect_lp(wpod_net, im2single(Ivehicle), bound_dim, lp_threshold=0.5)
# Out:
# (32, 56, 8)
# [<lib_detection.DLabel object at 0x000000003019D978>, <lib_detection.DLabel object at 0x000000003019DA58>]
# [<lib_detection.DLabel object at 0x000000003019D780>, <lib_detection.DLabel object at 0x000000003019D8D0>]

# %%
len(LpImg)
# Out:
# 2

# %%
plt.imshow(LpImg[0])

# %%
plt.imshow(LpImg[1])
