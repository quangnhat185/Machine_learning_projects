# %% [markdown]
# - Pandas: Library for data structrue and data analysis tool
# - Matplotlib:Ploting library which produces publication quality figures
# - Seaborn: Data visualization library based on matplotlib
# - Numpy: Library supports for large, multi-dimensional arrays and matrices
# - Scipy: Library which is used for scientific computing and technical computing
# - warning: Managermen warning in jupyter notebook environment

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns # data visualization library based on matplotlib
import numpy as np
# Scipy:
from scipy.stats import norm
from scipy import stats
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
data =pd.read_csv("auto-mpg.csv")

# %%
data.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# 5    15.0          8         429.0        198    4341          10.0
# 6    14.0          8         454.0        220    4354           9.0
# 7    14.0          8         440.0        215    4312           8.5
# 8    14.0          8         455.0        225    4425          10.0
# 9    15.0          8         390.0        190    3850           8.5
# 10   15.0          8         383.0        170    3563          10.0
# 11   14.0          8         340.0        160    3609           8.0
# 12   15.0          8         400.0        150    3761           9.5
# ...

# %%
data.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
data.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model year', 'origin', 'car name'],
#       dtype='object')

# %%
data.shape
# Out:
# (398, 9)

# %%
data.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  398.000000  398.000000    398.000000   398.000000    398.000000
# mean    23.514573    5.454774    193.425879  2970.424623     15.568090
# std      7.815984    1.701004    104.269838   846.841774      2.757689
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.250000  2223.750000     13.825000
# 50%     23.000000    4.000000    148.500000  2803.500000     15.500000
# 75%     29.000000    8.000000    262.000000  3608.000000     17.175000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#        model year      origin
# count  398.000000  398.000000
# mean    76.010050    1.572864
# std      3.697627    0.802055
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %%
data.mpg.describe()
# Out:
# count    398.000000
# mean      23.514573
# std        7.815984
# min        9.000000
# 25%       17.500000
# 50%       23.000000
# 75%       29.000000
# max       46.600000
# Name: mpg, dtype: float64

# %%
sns.distplot(data["mpg"])

# %% [markdown]
# ### Since horsepower is tring value, we need to convert it to float value

# %%
data.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower       object
# weight            int64
# acceleration    float64
# model year        int64
# origin            int64
# car name         object
# dtype: object

# %%
data['horsepower'] = pd.to_numeric(data['horsepower'],errors='coerce')

# %%
data.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower      float64
# weight            int64
# acceleration    float64
# model year        int64
# origin            int64
# car name         object
# dtype: object

# %%
data.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000000218D1E80>,
# ...
#       dtype=object)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from math import sqrt

# %% [markdown]
# ### Create data frame with considering values

# %%
X = data.drop(["mpg","car name","origin","cylinders"],axis=1)
y= data["mpg"]

# %%
X.fillna(X.mean(), inplace=True) #Remove n

X.head()
# Out:
#    displacement  horsepower  weight  acceleration  model year
# 0         307.0       130.0    3504          12.0          70
# 1         350.0       165.0    3693          11.5          70
# 2         318.0       150.0    3436          11.0          70
# 3         304.0       150.0    3433          12.0          70
# 4         302.0       140.0    3449          10.5          70

# %%
y.head()
# Out:
# 0    18.0
# 1    15.0
# 2    18.0
# 3    16.0
# 4    17.0
# Name: mpg, dtype: float64

# %%
y=np.log(y)
y
# Out:
# 0      2.890372
# 1      2.708050
# 2      2.890372
# 3      2.772589
# 4      2.833213
# 5      2.708050
# 6      2.639057
# 7      2.639057
# 8      2.639057
# 9      2.708050
# 10     2.708050
# 11     2.639057
# 12     2.708050
# 13     2.639057
# 14     3.178054
# 15     3.091042
# 16     2.890372
# 17     3.044522
# 18     3.295837
# 19     3.258097
# 20     3.218876
# 21     3.178054
# 22     3.218876
# 23     3.258097
# 24     3.044522
# 25     2.302585
# 26     2.302585
# 27     2.397895
# 28     2.197225
# 29     3.295837
#          ...
# 368    3.295837
# 369    3.526361
# 370    3.433987
# 371    3.367296
# 372    3.295837
# 373    3.178054
# 374    3.135494
# 375    3.583519
# 376    3.610918
# 377    3.433987
# 378    3.637586
# 379    3.583519
# 380    3.583519
# 381    3.583519
# 382    3.526361
# 383    3.637586
# 384    3.465736
# 385    3.637586
# 386    3.218876
# 387    3.637586
# 388    3.258097
# 389    3.091042
# 390    3.465736
# 391    3.583519
# ...

# %% [markdown]
# ### Scale and split our data values

# %%
X = StandardScaler().fit_transform(X)
X
# Out:
# array([[ 1.0906037 ,  0.66919608,  0.63086987, -1.29549834, -1.62742629],
#        [ 1.5035143 ,  1.58659918,  0.85433297, -1.47703779, -1.62742629],
#        [ 1.19623199,  1.19342642,  0.55047045, -1.65857724, -1.62742629],
#        ...,
#        [-0.56103873, -0.53653371, -0.79858454, -1.4407299 ,  1.62198339],
#        [-0.70507731, -0.66759129, -0.40841088,  1.10082237,  1.62198339],
#        [-0.71467988, -0.58895674, -0.29608816,  1.39128549,  1.62198339]])

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size = 0.33,random_state=42)
X_train.shape[0] == y_train.shape[0]
# Out:
# True

# %%
model = LinearRegression().fit(X_train, y_train)
y_pred=model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test, y_pred)
# Out:
# 0.01235732087706906

# %% [markdown]
# ### As we can see above, our model can predict pretty good with Linear regression model, let try with another ones

# %%
#SVR Support vector regression
from sklearn.svm import SVR
clf = SVR(gamma='scale', C=1.0, epsilon=0,)
clf.fit(X_train, y_train) 
y_pred=clf.predict(X_test)
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test, y_pred)
# Out:
# 0.009537628152785993

# %%
from sklearn.ensemble import GradientBoostingRegressor
gb_regressor = GradientBoostingRegressor(n_estimators=4000)
gb_regressor.fit(X_train,y_train)
mean_squared_error(y_test, y_pred)
# Out:
# 0.009537628152785993

# %% [markdown]
# ### Now let write a function in which the user input array data of "displacement", "horsepower", "weight", "acceleration", "model year" repectively and the model will proive the fuel efficiency in MPG

# %%
def SVR_predict(list_input):
    list_input= [float(i) for i in list_input]
    dataset_display = data.drop(["mpg","car name","origin","cylinders"],axis=1)
    df2=pd.DataFrame([list_input],columns=['displacement', 'horsepower', 'weight',"acceleration","model year"])
    dataset_display=dataset_display.append(df2,ignore_index=True)
    dataset_display = StandardScaler().fit_transform(dataset_display)
    y_pred=clf.predict(dataset_display[[len(dataset_display)-1]])
    
    return "Fuel efficieny value of the vehicle is : {} MPG".format(str(np.round(np.e**y_pred.max(),2)))

# %%
input_string = input("Input value of displacement, horsepower, weight, accleration and model year seperated by scape [5 values]: \n ")
list_input  = input_string.split()
SVR_predict(list_input)
# Out:
# Input value of displacement, horsepower, weight, accleration and model year seperated by scape [5 values]:
#  318.0	150.0	3436	11.0	70
# 'Fuel efficieny value of the vehicle is : 16.68 MPG'

# %%
input_string = input("Input value of displacement, horsepower, weight, accleration and model year seperated by scape [5 values]: \n ")
list_input  = input_string.split()
SVR_predict(list_input)
# Out:
# Input value of displacement, horsepower, weight, accleration and model year seperated by scape [5 values]:
#  282.0	145.0	3229	9	80
# 'Fuel efficieny value of the vehicle is : 19.87 MPG'
