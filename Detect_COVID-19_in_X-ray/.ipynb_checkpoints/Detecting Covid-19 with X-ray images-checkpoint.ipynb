# %% [markdown]
# ## Detect Covid-19 with X-ray images
#
# The dataset of this project is share by __Dr. Joseph Pau Cohen__ from University of Montreal in an attempt to predict and understand the infection. His repository when I downloaded the dataset can be found [here](https://github.com/ieee8023/covid-chestxray-dataset). Thank you so much for publishing such a valuable dataset for the community.!
#
# ### Please notice that any prediction delivered by the model is only for reference and educational purpose!

# %% [markdown]
# ### Data Visualization
#
# The datasets contain two categories: X-ray images of patients who were diagnosed with COVID-19 and patient who were normal. There are 25 images in each category.

# %%
import matplotlib.pyplot as plt
import cv2
import glob
import numpy as np
# %matplotlib.line
# Out:
# UsageError: Line magic function `%matplotlib.line` not found.

# %%
# declear a function to read image using cv2 and resize them to the same size as 480x480

def image_process(image):
    img = cv2.imread(image)
    img_rgb = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
    img_resize = cv2.resize(img_rgb,(224,224))
    return img_resize

# %%
# visulaize images in covid folders
covid_images = glob.glob("dataset/covid/*")
print("Found %i covid images" %len(covid_images))

fig=plt.figure(figsize=(10,14))
plt.rcParams["font.size"]=16
fig.suptitle("X-ray images of patient who were diagnosed wit COVID-19")
cols = 5
rows = 5
fig_list_covid = []

for i in range(cols*rows):
    fig_list_covid.append(fig.add_subplot(rows,cols,i+1))
    img = image_process(covid_images[i])
    plt.axis(False)
    plt.imshow(img)

plt.tight_layout(True)
plt.show()
# Out:
# Found 25 covid images

# %%
# visulaize images in normal folders
normal_images = glob.glob("dataset/normal/*")
print("Found %i covid images" %len(normal_images))

fig=plt.figure(figsize=(10,14))
plt.rcParams["font.size"]=16
fig.suptitle("X-ray images of patient who were normal")
cols = 5
rows = 5
fig_list_covid = []

for i in range(cols*rows):
    fig_list_covid.append(fig.add_subplot(rows,cols,i+1))
    img = image_process(normal_images[i])
    plt.axis(False)
    plt.imshow(img)

plt.tight_layout(True)
plt.show()
# Out:
# Found 25 covid images

# %%
# import required libraries and packages
import tensorflow
import keras
from keras.preprocessing.image import ImageDataGenerator
from keras.applications import ResNet50V2
from keras.optimizers import Adam
from keras.models import Sequential
from keras.models import Model
from keras.utils import to_categorical
from keras.layers import *
from keras.callbacks import ModelCheckpoint,EarlyStopping
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

# %% [markdown]
# ### Seperate raw data into input X and label y

# %%
X = [] # input data
y = [] # labels

for image in np.hstack([covid_images,normal_images]):
    img = image_process(image)
    X.append(img)
    y.append("covid") if "covid" in str(image) else y.append("normal") 
    
X = np.array(X)/255
y = np.array(y)

# convert binary label to one-hot encoding label
lb = LabelBinarizer()
y = lb.fit_transform(y)
y = to_categorical(y)

print("Shape of X: ", X.shape)
print("Shape of y: ", y.shape)
# Out:
# Shape of X:  (50, 224, 224, 3)
# Shape of y:  (50, 2)

# %%
# Split into train set and test set
(X_train,X_test,y_train, y_test) = train_test_split(X,y,test_size=0.15,random_state=42,stratify=y)
print("Train set: X_train %s y_train %s"%(X_train.shape, y_train.shape))
print("Test set: X_test %s y_test %s"%(X_test.shape, y_test.shape))
# Out:
# Train set: X_train (42, 224, 224, 3) y_train (42, 2)
# Test set: X_test (8, 224, 224, 3) y_test (8, 2)

# %%
# Data augumentation
image_gen = ImageDataGenerator(rotation_range=10, 
                               fill_mode="nearest")

# %%
# Load ResNet50V2 network and remove the head layers
ResNet = ResNet50V2(weights="imagenet", include_top = False, input_shape=(224,224,3))

# Free all layers in Resnet to prevent weight updating in those layers
# In this case only the last 4 layers are kept unfree
for layer in ResNet.layers:
    layer.trainable = False

# %%
# Constructing our model
def create_model(name_model):
    model = Sequential(name=name_model)
    model.add(ResNet)
    model.add(AveragePooling2D(pool_size=(4,4)))
    model.add(Flatten(name="flatten"))
    model.add(Dense(64,activation="relu"))
    model.add(Dense(128,activation="relu"))
    model.add(Dense(256,activation="relu"))
    model.add(Dropout(0.2))
    model.add(Dense(2,activation="softmax"))
    
    return model

model = create_model("Resnet50")
model.summary()
# Out:
# Model: "Resnet50"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Model)           (None, 7, 7, 2048)        23564800
# _________________________________________________________________
# average_pooling2d_12 (Averag (None, 1, 1, 2048)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dense_23 (Dense)             (None, 64)                131136
# _________________________________________________________________
# dense_24 (Dense)             (None, 128)               8320
# _________________________________________________________________
# dense_25 (Dense)             (None, 256)               33024
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_26 (Dense)             (None, 2)                 514
# =================================================================
# Total params: 23,737,794
# Trainable params: 172,994
# Non-trainable params: 23,564,800
# _________________________________________________________________

# %%
# configurign optimizer, epoch, loss metrics, hyperparameter
epochs = 25
lr = 1e-4
batch_size = 4

opt = Adam(lr=lr,decay=lr/epochs)
model.compile(loss="binary_crossentropy", optimizer=opt,metrics=["accuracy"])

# Save weight only if loss is reduced
checkpoint_filepath="covid_detection.h5"
my_checkpointer = [
    EarlyStopping(monitor='val_loss', patience=7, verbose=0),
    ModelCheckpoint(filepath=checkpoint_filepath,verbose=1, save_best_only=True)
                  ]

# %%
result = model.fit_generator(image_gen.flow(X_train,y_train,batch_size=batch_size),
                             steps_per_epoch=len(X_train)//batch_size,
                             validation_data=(X_test,y_test),
                             validation_steps=len(X_test)//batch_size,
                             epochs=epochs,callbacks=my_checkpointer)
# Out:
# Epoch 1/25
#  2/10 [=====>........................] - ETA: 49s - loss: 0.7312 - accuracy: 0.5000
# C:\ProgramData\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (1.127565). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# 10/10 [==============================] - 23s 2s/step - loss: 0.7052 - accuracy: 0.5000 - val_loss: 0.7026 - val_accuracy: 0.5000
#
# Epoch 00001: val_loss improved from inf to 0.70261, saving model to covid_detection.h5
# Epoch 2/25
# 10/10 [==============================] - 8s 783ms/step - loss: 0.7153 - accuracy: 0.4750 - val_loss: 0.6671 - val_accuracy: 0.5000
#
# Epoch 00002: val_loss improved from 0.70261 to 0.66713, saving model to covid_detection.h5
# Epoch 3/25
# 10/10 [==============================] - 7s 715ms/step - loss: 0.6713 - accuracy: 0.6389 - val_loss: 0.6427 - val_accuracy: 0.7500
#
# Epoch 00003: val_loss improved from 0.66713 to 0.64267, saving model to covid_detection.h5
# Epoch 4/25
# 10/10 [==============================] - 9s 902ms/step - loss: 0.6731 - accuracy: 0.5789 - val_loss: 0.6315 - val_accuracy: 0.7500
#
# Epoch 00004: val_loss improved from 0.64267 to 0.63152, saving model to covid_detection.h5
# Epoch 5/25
# 10/10 [==============================] - 8s 760ms/step - loss: 0.6140 - accuracy: 0.7632 - val_loss: 0.6086 - val_accuracy: 0.7500
#
# Epoch 00005: val_loss improved from 0.63152 to 0.60860, saving model to covid_detection.h5
# Epoch 6/25
# 10/10 [==============================] - 8s 839ms/step - loss: 0.6221 - accuracy: 0.6750 - val_loss: 0.5847 - val_accuracy: 0.7500
#
# Epoch 00006: val_loss improved from 0.60860 to 0.58471, saving model to covid_detection.h5
# Epoch 7/25
# 10/10 [==============================] - 8s 780ms/step - loss: 0.6119 - accuracy: 0.6316 - val_loss: 0.5653 - val_accuracy: 0.8750
#
# Epoch 00007: val_loss improved from 0.58471 to 0.56534, saving model to covid_detection.h5
# Epoch 8/25
# 10/10 [==============================] - 8s 757ms/step - loss: 0.6321 - accuracy: 0.6111 - val_loss: 0.5568 - val_accuracy: 0.7500
#
# Epoch 00008: val_loss improved from 0.56534 to 0.55684, saving model to covid_detection.h5
# Epoch 9/25
# 10/10 [==============================] - 8s 772ms/step - loss: 0.5912 - accuracy: 0.8000 - val_loss: 0.5409 - val_accuracy: 0.8750
#
# Epoch 00009: val_loss improved from 0.55684 to 0.54086, saving model to covid_detection.h5
# Epoch 10/25
# 10/10 [==============================] - 7s 748ms/step - loss: 0.5337 - accuracy: 0.8611 - val_loss: 0.5141 - val_accuracy: 0.8750
#
# Epoch 00010: val_loss improved from 0.54086 to 0.51409, saving model to covid_detection.h5
# Epoch 11/25
# 10/10 [==============================] - 8s 786ms/step - loss: 0.5553 - accuracy: 0.7750 - val_loss: 0.4914 - val_accuracy: 1.0000
#
# Epoch 00011: val_loss improved from 0.51409 to 0.49137, saving model to covid_detection.h5
# Epoch 12/25
# 10/10 [==============================] - 7s 739ms/step - loss: 0.4808 - accuracy: 0.8684 - val_loss: 0.4656 - val_accuracy: 0.8750
#
# Epoch 00012: val_loss improved from 0.49137 to 0.46560, saving model to covid_detection.h5
# Epoch 13/25
# 10/10 [==============================] - 8s 793ms/step - loss: 0.4811 - accuracy: 0.8421 - val_loss: 0.4449 - val_accuracy: 1.0000
#
# Epoch 00013: val_loss improved from 0.46560 to 0.44489, saving model to covid_detection.h5
# Epoch 14/25
# 10/10 [==============================] - 7s 742ms/step - loss: 0.4411 - accuracy: 0.8684 - val_loss: 0.4267 - val_accuracy: 0.8750
#
# Epoch 00014: val_loss improved from 0.44489 to 0.42670, saving model to covid_detection.h5
# Epoch 15/25
# 10/10 [==============================] - 8s 795ms/step - loss: 0.4664 - accuracy: 0.7632 - val_loss: 0.3966 - val_accuracy: 1.0000
#
# Epoch 00015: val_loss improved from 0.42670 to 0.39655, saving model to covid_detection.h5
# Epoch 16/25
# 10/10 [==============================] - 8s 818ms/step - loss: 0.3529 - accuracy: 0.9000 - val_loss: 0.3862 - val_accuracy: 0.7500
#
# Epoch 00016: val_loss improved from 0.39655 to 0.38617, saving model to covid_detection.h5
# Epoch 17/25
# 10/10 [==============================] - 7s 749ms/step - loss: 0.4878 - accuracy: 0.8333 - val_loss: 0.3715 - val_accuracy: 0.7500
#
# Epoch 00017: val_loss improved from 0.38617 to 0.37147, saving model to covid_detection.h5
# Epoch 18/25
# 10/10 [==============================] - 7s 740ms/step - loss: 0.3079 - accuracy: 0.8947 - val_loss: 0.3395 - val_accuracy: 0.8750
#
# Epoch 00018: val_loss improved from 0.37147 to 0.33949, saving model to covid_detection.h5
# Epoch 19/25
# 10/10 [==============================] - 8s 794ms/step - loss: 0.3254 - accuracy: 0.9500 - val_loss: 0.3657 - val_accuracy: 0.7500
#
# Epoch 00019: val_loss did not improve from 0.33949
# Epoch 20/25
# 10/10 [==============================] - 8s 780ms/step - loss: 0.3287 - accuracy: 0.8947 - val_loss: 0.3448 - val_accuracy: 0.7500
#
# Epoch 00020: val_loss did not improve from 0.33949
# Epoch 21/25
# 10/10 [==============================] - 8s 800ms/step - loss: 0.3316 - accuracy: 0.7778 - val_loss: 0.3096 - val_accuracy: 0.7500
#
# Epoch 00021: val_loss improved from 0.33949 to 0.30963, saving model to covid_detection.h5
# Epoch 22/25
# 10/10 [==============================] - 8s 821ms/step - loss: 0.3983 - accuracy: 0.8250 - val_loss: 0.3206 - val_accuracy: 0.7500
#
# Epoch 00022: val_loss did not improve from 0.30963
# Epoch 23/25
# 10/10 [==============================] - 8s 791ms/step - loss: 0.1767 - accuracy: 0.9737 - val_loss: 0.3148 - val_accuracy: 0.7500
#
# Epoch 00023: val_loss did not improve from 0.30963
# Epoch 24/25
# 10/10 [==============================] - 8s 825ms/step - loss: 0.3076 - accuracy: 0.8158 - val_loss: 0.3609 - val_accuracy: 0.7500
#
# Epoch 00024: val_loss did not improve from 0.30963
# Epoch 25/25
# 10/10 [==============================] - 8s 836ms/step - loss: 0.1473 - accuracy: 1.0000 - val_loss: 0.4083 - val_accuracy: 0.7500
#
# Epoch 00025: val_loss did not improve from 0.30963

# %%
plt.style.use("classic")
plt.figure()
plt.plot(result.history["val_loss"][:19], label="val_loss",color="red")
plt.plot(result.history["val_accuracy"][:19], label="val_acc",color="green")
plt.title("Validation loss and accuracy on COVID-19 Dataset")
plt.xlabel("Epoch")
plt.ylabel("Loss/Accuracy")
plt.ylim(0,1.5)
plt.xlim(0,14)
plt.legend(loc="lower left")
plt.grid("True")
plt.savefig("traning_result.png",dpi=300)
